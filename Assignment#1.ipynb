# %% [markdown]
# # Assignment 1

# %%
import pandas as pd

# %%
data=pd.read_csv('jsrt_metadata.csv')

# %%
data
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
data.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
data['diagnosis'].value_counts()
# Out:
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# ...

# %%
import numpy as num
m=data['diagnosis'].value_counts().idxmax()
data['diagnosis'].replace(num.nan,m,inplace=True)
data['diagnosis'].isnull().sum()
# Out:
# 0

# %%
m=data['subtlety'].value_counts().idxmax()
data['subtlety'].replace(num.nan,m,inplace=True)
m=data['size'].value_counts().idxmax()
data['size'].replace(num.nan,m,inplace=True)
m=data['age'].value_counts().idxmax()
data['age'].replace(num.nan,m,inplace=True)
m=data['x'].value_counts().idxmax()
data['x'].replace(num.nan,m,inplace=True)
m=data['y'].value_counts().idxmax()
data['y'].replace(num.nan,m,inplace=True)
m=data['position'].value_counts().idxmax()
data['position'].replace(num.nan,m,inplace=True)
data.replace("non-nodule",num.nan,inplace = True)
m=data['state'].value_counts().idxmax()
data['state'].replace(num.nan,m,inplace=True)
data.replace("unknown",num.nan,inplace = True)
m = data['diagnosis'].value_counts().idxmax()
data['diagnosis'].replace(num.nan,m, inplace = True)

# %%
data.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.hist(data['diagnosis'], color="lightblue",ec='black')
# Out:
# (array([157.,  45.,  11.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %%
data['diagnosis'].value_counts()
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# ...

# %%
plt.pyplot.pie(data['state'].value_counts(),explode = None,shadow = True,labels = ['Malignant','Benign'],autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25364a20fd0>,
# ...
#  [Text(-0.850588847327074, 0.6974945252851811, 'Malignant'),
#   Text(0.8505889126312205, -0.6974944456473027, 'Benign')],
#  [Text(-0.4639575530874948, 0.38045155924646235, '78.1%'),
#   Text(0.4639575887079384, -0.3804515158076196, '21.9%')])

# %%
for xx in list(data['diagnosis'].unique()):
    plt.pyplot.figure()
    plt.pyplot.pie(data.loc[data['diagnosis'] == xx]['gender'].value_counts(),labels=list(data.loc[data['diagnosis'] == xx]['gender'].value_counts().keys()), colors = ['lightblue','lightGreen'], autopct="%1f%%")
    print(data.loc[data['diagnosis'] == xx]['gender'].value_counts())
# Out:
# Female    78
# Male      75
# Name: gender, dtype: int64
# Female    1
# Male      1
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Male      9
# Female    5
# Name: gender, dtype: int64
# Male      6
# Female    2
# Name: gender, dtype: int64
# Female    15
# Male       8
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Male      1
# Female    1
# Name: gender, dtype: int64
# Female    4
# Male      3
# Name: gender, dtype: int64
# Female    2
# Name: gender, dtype: int64
# Male    2
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# Male    3
# Name: gender, dtype: int64
# Female    3
# Male      1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    2
# Male      2
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Male      1
# Female    1
# Name: gender, dtype: int64
# Male    1
# Name: gender, dtype: int64
# Female    1
# Name: gender, dtype: int64
# ...
